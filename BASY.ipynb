# %% [markdown]
# <a href="https://colab.research.google.com/github/Basy-Duke/Basy-Duke/blob/main/BASY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/crib (1).csv")

# %%
df.head()
# Out:
#    Property Ref     Added On Last Updated Market Status                  Type  \
# 0       2619053  13 Dec 2024  27 Mar 2025     Available                 House
# 1       2674076  21 Jan 2025  15 Apr 2025     Available       Terraced Duplex
# 2       2820608  15 Apr 2025  15 Apr 2025     Available  Semi-detached Duplex
# 3       2820575  15 Apr 2025  15 Apr 2025     Available       Detached Duplex
# 4       2790291  27 Mar 2025  15 Apr 2025     Available       Detached Duplex
#
#    Bedrooms  Bathrooms  Toilets  Parking Spaces Furnishing        Price  \
# 0       3.0        3.0      4.0             1.0  Furnished  110000000.0
# 1       4.0        4.0      5.0             3.0        NaN  530000000.0
# 2       5.0        7.0      6.0             4.0        NaN  850000000.0
# 3       5.0        5.0      6.0             5.0        NaN  450000000.0
# 4       4.0        4.0      5.0             3.0        NaN  250000000.0
#
#                District  State Servicing Service Charge Total Area  \
# 0                 Lekki  Lagos       NaN            NaN        NaN
# 1  Victoria Island (VI)  Lagos  Serviced            NaN        NaN
# 2                 Lekki  Lagos       NaN            NaN        NaN
# 3                 Lekki  Lagos       NaN            NaN        NaN
# 4                 Lekki  Lagos  Serviced            NaN        NaN
#
#   Covered Area
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.shape
# Out:
# (10157, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10157 entries, 0 to 10156
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Property Ref    10157 non-null  int64
#  1   Added On        10157 non-null  object
#  2   Last Updated    10157 non-null  object
#  3   Market Status   10157 non-null  object
#  4   Type            10157 non-null  object
#  5   Bedrooms        10061 non-null  float64
#  6   Bathrooms       9089 non-null   float64
#  7   Toilets         9297 non-null   float64
#  8   Parking Spaces  5705 non-null   float64
#  9   Furnishing      756 non-null    object
#  10  Price           10157 non-null  float64
#  11  District        10157 non-null  object
#  12  State           10157 non-null  object
#  13  Servicing       744 non-null    object
#  14  Service Charge  119 non-null    object
#  15  Total Area      2086 non-null   object
#  16  Covered Area    1636 non-null   object
# dtypes: float64(5), int64(1), object(11)
# memory usage: 1.3+ MB

# %%
df1 = df.copy()

# %%
df['Property Ref'].duplicated().sum()
# Out:
# np.int64(6269)

# %%
df.duplicated().sum()
# Out:
# np.int64(5253)

# %%
df['Property Ref'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10152    False
# 10153    False
# 10154    False
# 10155    False
# 10156    False
# Name: Property Ref, Length: 10157, dtype: bool

# %%
duplicated_property_ref_rows = df[df['Property Ref'].duplicated()]
display(duplicated_property_ref_rows)
# Out:
#        Property Ref     Added On Last Updated Market Status  \
# 43          2820538  15 Apr 2025  15 Apr 2025     Available
# 44          2820535  15 Apr 2025  15 Apr 2025     Available
# 47          2816092  12 Apr 2025  15 Apr 2025     Available
# 48          2820530  15 Apr 2025  15 Apr 2025     Available
# 49          2820508  15 Apr 2025  15 Apr 2025     Available
# ...             ...          ...          ...           ...
# 10067       2628166  20 Dec 2024  07 May 2025     Available
# 10088       2726019  18 Feb 2025  22 Apr 2025     Available
# 10109       1863506  13 Aug 2023  11 May 2025     Available
# 10130       1788604  24 Jun 2023  18 Apr 2025     Available
# 10151       1788604  24 Jun 2023  18 Apr 2025     Available
#
#                        Type  Bedrooms  Bathrooms  Toilets  Parking Spaces  \
# 43     Semi-detached Duplex       4.0        4.0      5.0             NaN
# 44          Terraced Duplex       4.0        4.0      5.0             NaN
# 47     Semi-detached Duplex       4.0        4.0      5.0             2.0
# 48     Semi-detached Duplex       5.0        5.0      5.0             3.0
# 49          Detached Duplex       4.0        4.0      5.0             4.0
# ...                     ...       ...        ...      ...             ...
# 10067       Detached Duplex       4.0        4.0      5.0             3.0
# 10088       Detached Duplex       5.0        5.0      6.0             NaN
# 10109       Detached Duplex       5.0        5.0      6.0             4.0
# 10130  Semi-detached Duplex       5.0        6.0      7.0             5.0
# 10151  Semi-detached Duplex       5.0        6.0      7.0             5.0
#
#       Furnishing        Price District  State Servicing Service Charge  \
# 43           NaN  200000000.0    Lekki  Lagos       NaN            NaN
# 44           NaN  270000000.0    Lekki  Lagos       NaN            NaN
# 47           NaN  280000000.0    Lekki  Lagos       NaN            NaN
# 48           NaN  140000000.0    Lekki  Lagos       NaN            NaN
# 49           NaN  180000000.0    Lekki  Lagos       NaN            NaN
# ...          ...          ...      ...    ...       ...            ...
# 10067        NaN  950000000.0    Lekki  Lagos       NaN            NaN
# 10088        NaN  400000000.0    Lekki  Lagos       NaN            NaN
# 10109        NaN  330000000.0    Lekki  Lagos       NaN            NaN
# 10130  Furnished  260000000.0     Ajah  Lagos       NaN            NaN
# 10151  Furnished  260000000.0     Ajah  Lagos       NaN            NaN
#
#       Total Area Covered Area
# 43           NaN          NaN
# 44           NaN          NaN
# 47           NaN          NaN
# 48           NaN          NaN
# 49           NaN          NaN
# ...          ...          ...
# 10067        NaN          NaN
# 10088        NaN          NaN
# 10109    346 sqm          NaN
# 10130    500 sqm      250 sqm
# 10151    500 sqm      250 sqm
#
# [6269 rows x 17 columns]

# %%
df[df['Property Ref'] == 2820538]
# Out:
#       Property Ref     Added On Last Updated Market Status  \
# 23         2820538  15 Apr 2025  15 Apr 2025     Available
# 43         2820538  15 Apr 2025  15 Apr 2025     Available
# 1317       2820538  15 Apr 2025  15 Apr 2025     Available
# 8455       2820538  15 Apr 2025  15 Apr 2025     Available
# 9245       2820538  15 Apr 2025  15 Apr 2025     Available
#
#                       Type  Bedrooms  Bathrooms  Toilets  Parking Spaces  \
# 23    Semi-detached Duplex       4.0        4.0      5.0             NaN
# 43    Semi-detached Duplex       4.0        4.0      5.0             NaN
# 1317  Semi-detached Duplex       4.0        4.0      5.0             NaN
# 8455  Semi-detached Duplex       4.0        4.0      5.0             NaN
# 9245  Semi-detached Duplex       4.0        4.0      5.0             NaN
#
#      Furnishing        Price District  State Servicing Service Charge  \
# 23          NaN  200000000.0    Lekki  Lagos       NaN            NaN
# 43          NaN  200000000.0    Lekki  Lagos       NaN            NaN
# 1317        NaN  200000000.0    Lekki  Lagos       NaN            NaN
# 8455        NaN  200000000.0    Lekki  Lagos       NaN            NaN
# 9245        NaN  200000000.0    Lekki  Lagos       NaN            NaN
#
#      Total Area Covered Area
# 23          NaN          NaN
# 43          NaN          NaN
# 1317        NaN          NaN
# 8455        NaN          NaN
# 9245        NaN          NaN

# %%
df[df['Property Ref'] == 2816092]
# Out:
#       Property Ref     Added On Last Updated Market Status  \
# 25         2816092  12 Apr 2025  15 Apr 2025     Available
# 47         2816092  12 Apr 2025  15 Apr 2025     Available
# 1324       2816092  12 Apr 2025  15 Apr 2025     Available
# 8452       2816092  12 Apr 2025  08 May 2025     Available
# 9243       2816092  12 Apr 2025  08 May 2025     Available
#
#                       Type  Bedrooms  Bathrooms  Toilets  Parking Spaces  \
# 25    Semi-detached Duplex       4.0        4.0      5.0             2.0
# 47    Semi-detached Duplex       4.0        4.0      5.0             2.0
# 1324  Semi-detached Duplex       4.0        4.0      5.0             2.0
# 8452  Semi-detached Duplex       4.0        4.0      5.0             2.0
# 9243  Semi-detached Duplex       4.0        4.0      5.0             2.0
#
#      Furnishing        Price District  State Servicing Service Charge  \
# 25          NaN  280000000.0    Lekki  Lagos       NaN            NaN
# 47          NaN  280000000.0    Lekki  Lagos       NaN            NaN
# 1324        NaN  280000000.0    Lekki  Lagos       NaN            NaN
# 8452        NaN  280000000.0    Lekki  Lagos       NaN            NaN
# 9243        NaN  280000000.0    Lekki  Lagos       NaN            NaN
#
#      Total Area Covered Area
# 25          NaN          NaN
# 47          NaN          NaN
# 1324        NaN          NaN
# 8452        NaN          NaN
# 9243        NaN          NaN

# %%
len(df.index)
# Out:
# 10157

# %%
df.drop_duplicates(subset=['Property Ref'], inplace=True)
len(df.index)
# Out:
# 3888

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Property Ref         0
# Added On             0
# Last Updated         0
# Market Status        0
# Type                 0
# Bedrooms            48
# Bathrooms          419
# Toilets            338
# Parking Spaces    1755
# Furnishing        3591
# Price                0
# District             0
# State                0
# Servicing         3612
# Service Charge    3851
# Total Area        3181
# Covered Area      3349
# dtype: int64

# %%
df.drop(columns=['Furnishing','Servicing','Service Charge','Total Area','Covered Area'], inplace=True)

# %%
df.columns
# Out:
# Index(['Property Ref', 'Added On', 'Last Updated', 'Market Status', 'Type',
#        'Bedrooms', 'Bathrooms', 'Toilets', 'Parking Spaces', 'Price',
#        'District', 'State'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Property Ref         0
# Added On             0
# Last Updated         0
# Market Status        0
# Type                 0
# Bedrooms            48
# Bathrooms          419
# Toilets            338
# Parking Spaces    1755
# Price                0
# District             0
# State                0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Property Ref       0.000000
# Added On           0.000000
# Last Updated       0.000000
# Market Status      0.000000
# Type               0.000000
# Bedrooms           1.234568
# Bathrooms         10.776749
# Toilets            8.693416
# Parking Spaces    45.138889
# Price              0.000000
# District           0.000000
# State              0.000000
# dtype: float64

# %%
df['Bedrooms'].mean()
# Out:
# np.float64(4.394791666666666)

# %%
median_bedrooms = df['Bedrooms'].median()
median_bedrooms
# Out:
# 4.0

# %%
df['Bedrooms'].isna().sum()
# Out:
# np.int64(48)

# %%
df.fillna({'Bedrooms':median_bedrooms}, inplace=True)

# %%
df['Bedrooms'].isna().sum()
# Out:
# np.int64(0)

# %%
# Fill nulls in 'Bathrooms' and 'Toilets' based on 'Bedrooms'
df['Bathrooms'] = df.apply(lambda row: row['Bedrooms'] if pd.isna(row['Bathrooms']) else row['Bathrooms'], axis=1)
df['Toilets'] = df.apply(lambda row: row['Bedrooms'] if pd.isna(row['Toilets']) else row['Toilets'], axis=1)

# %%
df.isnull().sum()
# Out:
# Property Ref         0
# Added On             0
# Last Updated         0
# Market Status        0
# Type                 0
# Bedrooms             0
# Bathrooms            0
# Toilets              0
# Parking Spaces    1755
# Price                0
# District             0
# State                0
# dtype: int64

# %%
df[df['Parking Spaces'].isnull()]
# Out:
#        Property Ref     Added On Last Updated Market Status             Type  \
# 5           2820596  15 Apr 2025  15 Apr 2025     Available  Detached Duplex
# 6           2820573  15 Apr 2025  15 Apr 2025     Available  Detached Duplex
# 7           2820611  15 Apr 2025  15 Apr 2025     Available  Terraced Duplex
# 8           2820598  15 Apr 2025  15 Apr 2025     Available  Detached Duplex
# 9           2820591  15 Apr 2025  15 Apr 2025     Available   Block of Flats
# ...             ...          ...          ...           ...              ...
# 10149       2752501  05 Mar 2025  13 May 2025     Available  Detached Duplex
# 10152       2806998  07 Apr 2025  09 May 2025     Available            House
# 10153       2807023  07 Apr 2025  08 May 2025     Available  Terraced Duplex
# 10155       2776147  19 Mar 2025  24 Apr 2025     Available   Block of Flats
# 10156       2807071  07 Apr 2025  12 May 2025     Available   Block of Flats
#
#        Bedrooms  Bathrooms  Toilets  Parking Spaces         Price  \
# 5           5.0        5.0      6.0             NaN  3.500000e+08
# 6           4.0        4.0      5.0             NaN  5.000000e+08
# 7           4.0        4.0      5.0             NaN  3.000000e+08
# 8           4.0        4.0      5.0             NaN  5.000000e+08
# 9           2.0        2.0      3.0             NaN  7.300000e+07
# ...         ...        ...      ...             ...           ...
# 10149       6.0        6.0      6.0             NaN  3.400000e+09
# 10152       2.0        4.0      4.0             NaN  1.800000e+08
# 10153       4.0        4.0      5.0             NaN  3.000000e+08
# 10155     111.0      111.0    112.0             NaN  2.500000e+09
# 10156       4.0        1.0     22.0             NaN  6.500000e+07
#
#                District  State
# 5                 Lekki  Lagos
# 6                 Lekki  Lagos
# 7                 Lekki  Lagos
# 8                 Lekki  Lagos
# 9                 Lekki  Lagos
# ...                 ...    ...
# 10149  Maitama District  Abuja
# 10152             Lekki  Lagos
# 10153             Lekki  Lagos
# 10155           Katampe  Abuja
# 10156       Ibeju Lekki  Lagos
#
# [1755 rows x 12 columns]

# %%
df['Parking Spaces'].mean()
# Out:
# np.float64(6.170182841068917)

# %%
df['Parking Spaces'].median()
# Out:
# 4.0

# %%
sns.boxplot(x=df['Parking Spaces'])
plt.title('Boxplot of Parking Spaces')
plt.xlabel('Parking Spaces')
plt.show()
